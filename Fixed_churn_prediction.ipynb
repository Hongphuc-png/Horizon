# %%
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# **1. Load data**

# %%
import pandas as pd

# %%
import pandas as pd
df_data = pd.read_csv('/content/Sales_Performance_Cleaned_Python.csv')
df_data.head()
# Out:
#    Product Id  Order Id  Customer Id    Category Name            Channel  \
# 0           2         4           81         COW_MILK  CONVENIENCE_STORE
# 1          11         4           81  DRINKING_YOGURT  CONVENIENCE_STORE
# 2          17         6           29         COW_MILK  CONVENIENCE_STORE
# 3          13         6           29  DRINKING_YOGURT  CONVENIENCE_STORE
# 4           6         8          406         COW_MILK  CONVENIENCE_STORE
#
#   Response       Date  Gender Location Preferred Com Channel  \
# 0      No   3/20/2024  FEMALE    HANOI                 EMAIL
# 1      No   3/20/2024  FEMALE    HANOI                 EMAIL
# 2      No   3/28/2024  FEMALE    HANOI                 EMAIL
# 3      No   3/28/2024  FEMALE    HANOI                 EMAIL
# 4      No    4/8/2024  FEMALE    HANOI                  CALL
#
#             Product Name  Age  Quantity  Total Price  Unit Price  Unit Cost  \
# 0          Dairyease 180   39         4       136000       34000      22000
# ...

# %%
df_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33011 entries, 0 to 33010
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Product Id             33011 non-null  int64
#  1   Order Id               33011 non-null  int64
#  2   Customer Id            33011 non-null  int64
#  3   Category Name          33011 non-null  object
#  4   Channel                33011 non-null  object
#  5   Response               33011 non-null  object
#  6   Date                   33011 non-null  object
#  7   Gender                 33011 non-null  object
#  8   Location               33011 non-null  object
#  9   Preferred Com Channel  33011 non-null  object
#  10  Product Name           33011 non-null  object
#  11  Age                    33011 non-null  int64
#  12  Quantity               33011 non-null  int64
#  13  Total Price            33011 non-null  int64
# ...

# %% [markdown]
# **2. Analytics**

# %%
df_data.loc[df_data.Churn=='No','Churn'] = 0
df_data.loc[df_data.Churn=='Yes','Churn'] = 1

# %%
df_data['Churn'] = df_data['Response'].apply(lambda x: 1 if x == 'Yes' else 0)
df_data.head()
# Out:
#    Product Id  Order Id  Customer Id    Category Name            Channel  \
# 0           2         4           81         COW_MILK  CONVENIENCE_STORE
# 1          11         4           81  DRINKING_YOGURT  CONVENIENCE_STORE
# 2          17         6           29         COW_MILK  CONVENIENCE_STORE
# 3          13         6           29  DRINKING_YOGURT  CONVENIENCE_STORE
# 4           6         8          406         COW_MILK  CONVENIENCE_STORE
#
#   Response       Date  Gender Location Preferred Com Channel  \
# 0      No   3/20/2024  FEMALE    HANOI                 EMAIL
# 1      No   3/20/2024  FEMALE    HANOI                 EMAIL
# 2      No   3/28/2024  FEMALE    HANOI                 EMAIL
# 3      No   3/28/2024  FEMALE    HANOI                 EMAIL
# 4      No    4/8/2024  FEMALE    HANOI                  CALL
#
#             Product Name  Age  Quantity  Total Price  Unit Price  Unit Cost  \
# 0          Dairyease 180   39         4       136000       34000      22000
# ...

# %%
import plotly.graph_objects as go
import plotly.offline as pyoff

df_plot = df_data.groupby('Gender').Churn.mean().reset_index()
plot_data = [
    go.Bar(
        x=df_plot['Gender'],
        y=df_plot['Churn'],
        width = [0.5, 0.5],
        marker=dict(
        color=['green', 'blue'])
    )
]
plot_layout = go.Layout(
        xaxis={"type": "category"},
        yaxis={"title": "Churn Rate"},
        title='Gender',
        plot_bgcolor  = 'rgb(243,243,243)',
        paper_bgcolor  = 'rgb(243,243,243)',
    )
fig = go.Figure(data=plot_data, layout=plot_layout)
pyoff.iplot(fig)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.graph_objects as go
import plotly.offline as pyoff

# %%
df_data.groupby('Gender').Churn.mean()
# Out:
# Gender
# FEMALE    0.835794
# MALE      0.885000
# Name: Churn, dtype: float64
