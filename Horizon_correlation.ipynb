# %%
import pandas as pd

# Load the data into a pandas DataFrame
# Replace 'your_data.csv' with the actual path to your CSV file
df = pd.read_csv('/content/Sales-Performance.1.csv')

print("/content/Sales-Performance.1.csv")
# Optionally, you can create a dummy DataFrame for demonstration
# df = pd.DataFrame({
#     'Age': [1, 2, 3, 4, 5],
#     'Quantity': [5, 4, 3, 2, 1],
#     'Total Price': [3, 4, 5, 1, 2],
#     'Unit Price': [2, 3, 4, 5, 1],
#     'Unit Cost': [4, 5, 1, 2, 3],
#     'Total Cost': [1, 2, 3, 4, 5],
#     'Profit': [5, 1, 2, 3, 4],
# })

# %%
import pandas as pd
import scipy.stats as stats
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np # Import numpy

# Load the data into a pandas DataFrame
# Replace 'your_data.csv' with the actual path to your CSV file
df = pd.read_csv('/content/Sales-Performance.1.csv')


# Factor importance correlation matrix
factor_cols = ['Age', 'Quantity', 'Total Price',
'Unit Price', 'Unit Cost', 'Total Cost',
'Profit',]
# Removed the incorrect correlation calculation involving non-numeric columns
# correlation_matrix = df[factor_cols + ['Category Name']].corr()
# display(correlation_matrix)

# --------------------
# Correlation Analysis
# --------------------
factor_cols = ['Age', 'Quantity', 'Total Price',
'Unit Price', 'Unit Cost', 'Total Cost',
'Profit',]

plt.figure(figsize=(12, 8))
numeric_df = df.select_dtypes(include=[np.number])
correlation_matrix = numeric_df.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', center=0)
plt.title('Correlation Matrix of Numerical Variables')
plt.tight_layout()
plt.show()
